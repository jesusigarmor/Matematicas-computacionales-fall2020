# %%
2**100000+1
# Out:
# ...

# %%
[-2**64/2, 2**64/2]
# Out:
# [-9.223372036854776e+18, 9.223372036854776e+18]

# %%
import sys
print(sys.maxsize)
print(2**64/2+1)
# Out:
# 9223372036854775807
# 9.223372036854776e+18

# %%
bin(123)
# Out:
# '0b1111011'

# %%
print?

# %%
for i in range(0,5):
    print("%d \t %s" % (i, bin(i)))
# Out:
# 0 	 0b0
# 1 	 0b1
# 2 	 0b10
# 3 	 0b11
# 4 	 0b100

# %%
x = 0.0
while not x == 1.0:
    x = x + 0.1
    print("x=%19.17g" % (x))

# %%
x = 0.0
for i in range(0,15):
    x = x + 0.1
    print("x=%19.17g" % (x))
# Out:
# x=0.10000000000000001
# x=0.20000000000000001
# x=0.30000000000000004
# x=0.40000000000000002
# x=                0.5
# x=0.59999999999999998
# x=0.69999999999999996
# x=0.79999999999999993
# x=0.89999999999999991
# x=0.99999999999999989
# x= 1.0999999999999999
# x=                1.2
# x=                1.3
# x= 1.4000000000000001
# x= 1.5000000000000002

# %%
x = 0.0
while abs(x -1.0) > 1e-10:
    x = x + 0.1
    print ("x=%19.17g" % (x))
# Out:
# x=0.10000000000000001
# x=0.20000000000000001
# x=0.30000000000000004
# x=0.40000000000000002
# x=                0.5
# x=0.59999999999999998
# x=0.69999999999999996
# x=0.79999999999999993
# x=0.89999999999999991
# x=0.99999999999999989

# %%
from sympy.interactive import printing
printing.init_printing(use_latex=True)

# %%
from sympy import Symbol
x = Symbol('x')

# %%
x
# Out:
# x

# %%
type(x)
# Out:
# sympy.core.symbol.Symbol

# %%
y = Symbol('y')

# %%
import sympy as sym
x,y,z = sym.symbols('x,y,z')
x + 2*y + 3*z -x
# Out:
# 2⋅y + 3⋅z

# %%
a = sym.Rational(1,10)
a
# Out:
# 1/10

# %%
from sympy import *

# %%
diff(10+3*x+4*x**2+45*x*y, x,y)
# Out:
# 45

# %%
10+3*x+4*x**2+45*x*y
# Out:
#    2
# 4⋅x  + 45⋅x⋅y + 3⋅x + 10

# %%
diff(10+3*x+4*x**2+45*x*y, x).subs(x, 1)
# Out:
# 45⋅y + 11

# %%
a = sym.Rational(1,10)
a
# Out:
# 1/10

# %%
b = sym.Rational(45,67)
b
# Out:
# 45
# ──
# 67

# %%
c = a*b
c
# Out:
# 9/134

# %%
c.evalf()
# Out:
# 0.0671641791044776

# %%
import

# %%
m = Symbol('m')
s = Symbol('s')
theta = Symbol('theta')
v0 = Symbol('v0')
g = Symbol('g')
alturamaxima = ((v0**2)*(sin(theta))**2/g)
distancia = ((v0**2)*sin(2*theta)**2/g)
tiempodevuelo = 2*v0*sin(theta)/g

# %%
alturamaxima
# Out:
#   2    2
# v₀ ⋅sin (θ)
# ───────────
#      g

# %%
distancia
# Out:
#   2    2
# v₀ ⋅sin (2⋅θ)
# ─────────────
#       g

# %%
tiempodevuelo
# Out:
# 2⋅v₀⋅sin(θ)
# ───────────
#      g

# %%
alturamaxima.subs(v0, 10*m/s).subs(g, 9.8*m/s**2).subs(theta, pi/2)
# Out:
# 10.2040816326531⋅m

# %%
distancia.subs(v0, 10*m/s).subs(g, 9.8*m/s**2).subs(theta, pi/2)
# Out:
# 0

# %%
tiempodevuelo.subs(v0, 10*m/s).subs(g, 9.8*m/s**2).subs(theta, pi/2)
# Out:
# 2.04081632653061⋅s

# %%
Derivative?

# %%
y = Function('y')
x = Symbol('x')
y_ = Derivative(y(x), x)

# %%
ode = y_ + 10*y(x) + 3*y(x)**2
ode
# Out:
#    2                d
# 3⋅y (x) + 10⋅y(x) + ──(y(x))
#                     dx
