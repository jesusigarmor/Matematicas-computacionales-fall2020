# %% [markdown]
# ## Ejercicios de clase
#
# ### 15/Sep/2020

# %% [markdown]
# <div class="alert alert-info">
# **Ejercicio** Crea una figura, en la que muestres en un arreglo de $2 \times 2$  los _subplots_ de $x \cos x$, $x^2 \cos x$, $x^3 \cos x$ y $x^4 \cos x$.
# <br/>
# **Ejercicio** Repite las instrucciones pero ahora dibujalas todas en una misma gráfica, utilizando diferentes colores.
# <br/>
# **NOTA**: En ambas usa calidad profesional
# </div>

# %%
# %pylab inline
import numpy as np 
import matplotlib.pyplot as plt
from sympy import Symbol
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/conda/lib/python3.8/site-packages/IPython/core/magics/pylab.py:159: UserWarning: pylab import has clobbered these variables: ['cos']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
x = np.linspace(-1, 1.)
cos = np.cos(x)
X = cos*x
X2 = cos*(x**2)
X3 = cos*(x**3)
X4 = cos*(x**4)

# %%
plt.figure(figsize=(8, 6), dpi=80)

plt.plot(x,X, color = "red", label="x*cos(x)")
plt.plot(x, X2, color = "green", label="(x^2)*cos(x)")
plt.plot(x, X3, color = "brown", label="(x^3)*cos(x)")
plt.plot(x, X4, color = "blue", label="(x^4)*cos(x)")
plt.legend(loc='lower right')
plt.title("Gráfica de potencias de x multiplicadas por coseno\n")


plt.xlim(x.min() * 1.1, x.max() * 1.1)


ax = plt.gca()  # gca stands for 'get current axis'
ax.spines['right'].set_color('none')   # El borde de la gráfica sin color. Borde derecho 
ax.spines['top'].set_color('none')     # El borde de la gráfica sin color. Borde superior
ax.xaxis.set_ticks_position('bottom')      #Etiquetas del eje x debajo
ax.spines['bottom'].set_position(('data',0))   #Posicionas los datos alrededor de cero
ax.yaxis.set_ticks_position('left')      #Etiquetas del eje y a la izquierda
ax.spines['left'].set_position(('data',0))   #Centras los datos alrededor de cero

# %%
fig, ax = plt.subplots(2,2, figsize=(10,10))   #La primera pareja ordenada te dice como van a estar organizados los subplots
ax[0,0].plot(x,X, color = "red", label="x*cos(x)")

ax[0,1].plot(x,X2, color = "green", label="(x^2)*cos(x)")

ax[1,0].plot(x,X3, color = "brown", label="(x^3)*cos(x)")

ax[1,1].plot(x,X4, color = "black", label="(x^4)*cos(x)")
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# <div class="alert alert-info">
# **Ejercicio** Cambia la segunda línea del archivo a _¿Cómo has estado?_ ¿Qué sucede?
# </div>

# %%
# %%file inout.dat
# Hola, desde el archivo
# Este es un archivo de texto
# Escrito en ASCII
# Out:
# Overwriting inout.dat

# %%
contents = open('inout.dat').read()
out = open('my_output.dat', 'w')
out.write(contents.replace(' ', '_'))
out.close()

# %%
# !cat my_output.dat
# Out:
# Hola,_desde_el_archivo
# Este_es_un_archivo_de_texto
# Escrito_en_ASCII
