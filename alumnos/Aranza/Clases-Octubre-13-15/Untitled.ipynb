# %% [markdown]
# ## Visualización con R

# %%
library(ggthemes)
library(ggplot2)
library(dplyr)
library(MASS)
library(gridExtra)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘MASS’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     select
#
#
#
# Attaching package: ‘gridExtra’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine

# %%
data(Fleiss93, package = 'meta')
# Out:
# Error in find.package(package, lib.loc, verbose = verbose): there is no package called ‘meta’
# Traceback:
#
# 1. data(Fleiss93, package = "meta")
# 2. find.package(package, lib.loc, verbose = verbose)

# %%
data(oly12, package="VGAMdata")
# Out:
# Error in find.package(package, lib.loc, verbose = verbose): there is no package called ‘VGAMdata’
# Traceback:
#
# 1. data(oly12, package = "VGAMdata")
# 2. find.package(package, lib.loc, verbose = verbose)

# %%
data(Cars93, package="MASS")

# %%
ggplot(Cars93, aes(Weight, MPG.city)) + geom_point() +
       geom_smooth(colour="green") + ylim(0,50)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
data(father.son, package="UsingR")
# Out:
# Error in find.package(package, lib.loc, verbose = verbose): there is no package called ‘UsingR’
# Traceback:
#
# 1. data(father.son, package = "UsingR")
# 2. find.package(package, lib.loc, verbose = verbose)

# %%
library(ggplot2movies)
# Out:
# Error in library(ggplot2movies): there is no package called ‘ggplot2movies’
# Traceback:
#
# 1. library(ggplot2movies)

# %%
ggplot(movies, aes(votes, rating)) + geom_point() + ylim(1,10)
# Out:
# Error in ggplot(movies, aes(votes, rating)): object 'movies' not found
# Traceback:
#
# 1. ggplot(movies, aes(votes, rating))

# %%
Fleiss93 <- within(Fleiss93, {
                   total <- n.e + n.c
                   st <- reorder(study, -(total)) })
ggplot(Fleiss93, aes(st, total)) + geom_bar(stat="identity") +
       xlab("") + ylab("") + ylim(0,20000)
# Out:
# Error in within(Fleiss93, {: object 'Fleiss93' not found
# Traceback:
#
# 1. within(Fleiss93, {
#  .     total <- n.e + n.c
#  .     st <- reorder(study, -(total))
#  . })

# %%
Titanic1 <- data.frame(Titanic)
p <- ggplot(Titanic1, aes(weight=Freq)) +
            ylab("") + ylim(0,2250)
cs <- p + aes(Class) + geom_bar(fill="blue")
sx <- p + aes(Sex) + geom_bar(fill="green")
ag <- p + aes(Age) + geom_bar(fill="tan2")
su <- p + aes(Survived) + geom_bar(fill="red")
grid.arrange(cs, sx, ag, su, nrow=1, widths=c(3, 2, 2, 2))
# Out:
# plot without title

# %%
ggplot(oly12, aes(Height, Weight)) + geom_point() +
       ggtitle("Athletes at the London Olympics 2012")
# Out:
# Error in ggplot(oly12, aes(Height, Weight)): object 'oly12' not found
# Traceback:
#
# 1. ggplot(oly12, aes(Height, Weight))

# %%
ggplot(movies, aes(votes, rating)) + geom_point() + ylim(1,10)
