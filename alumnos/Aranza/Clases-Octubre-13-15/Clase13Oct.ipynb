# %% [markdown]
# ## Clase 13 de Oct
# #### Ggplot

# %%
library(ggplot2)

# %%
ggplot(iris, aes(Petal.Length)) + geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
library(ggthemes)

# %%
ggplot(iris, aes(Petal.Length, Petal.Width, color=Species)) +
       geom_point() + theme(legend.position="bottom") +
       scale_colour_colorblind()
# Out:
# plot without title

# %%
data(SpeedSki, package = "GDAdata")
# Out:
# Error in find.package(package, lib.loc, verbose = verbose): there is no package called ‘GDAdata’
# Traceback:
#
# 1. data(SpeedSki, package = "GDAdata")
# 2. find.package(package, lib.loc, verbose = verbose)

# %%
ggplot(SpeedSki, aes(x=Speed, fill=Sex)) + xlim(160, 220) +
       geom_histogram(binwidth=2.5) + xlab("Speed (km/hr)") +
       facet_wrap(~Sex, ncol=1) + ylab("") +
       theme(legend.position="none")
# Out:
# Error in ggplot(SpeedSki, aes(x = Speed, fill = Sex)): object 'SpeedSki' not found
# Traceback:
#
# 1. ggplot(SpeedSki, aes(x = Speed, fill = Sex))

# %% [markdown]
# ## Ejercicio de la luz

# %%
library(MASS)

# %%
vl <- data.frame(michelson)

# %%
vl
# Out:
#     Speed Run Expt
# 1    850  1   1
# 2    740  2   1
# 3    900  3   1
# 4   1070  4   1
# 5    930  5   1
# 6    850  6   1
# 7    950  7   1
# 8    980  8   1
# 9    980  9   1
# 10   880  10  1
# 11  1000  11  1
# 12   980  12  1
# 13   930  13  1
# 14   650  14  1
# 15   760  15  1
# 16   810  16  1
# 17  1000  17  1
# 18  1000  18  1
# 19   960  19  1
# 20   960  20  1
# 21   960  1   2
# 22   940  2   2
# 23   960  3   2
# 24   940  4   2
# 25   880  5   2
# 26   800  6   2
# 27   850  7   2
# 28   880  8   2
# 29   900  9   2
# 30   840  10  2
# ⋮   ⋮     ⋮   ⋮
# 71  910   11  4
# 72  920   12  4
# 73  890   13  4
# 74  860   14  4
# 75  880   15  4
# 76  720   16  4
# 77  840   17  4
# 78  850   18  4
# 79  850   19  4
# 80  780   20  4
# 81  890   1   5
# 82  840   2   5
# 83  780   3   5
# 84  810   4   5
# 85  760   5   5
# 86  810   6   5
# 87  790   7   5
# 88  810   8   5
# 89  820   9   5
# 90  850   10  5
# 91  870   11  5
# 92  870   12  5
# 93  810   13  5
# ...

# %%
ggplot(vl, aes(Speed, fill=Expt)) +
       geom_histogram(binwidth = 10) + xlab("Run") +
       ylab("Speed") + facet_grid(Run~Expt) +
       theme(legend.position="none")
# Out:
# plot without title

# %%
ggplot(vl, aes(Speed, fill=Expt)) +
       geom_histogram(binwidth = 10) + xlab("Run") +
       ylab("Speed") + 
       theme(legend.position="none")
# Out:
# plot without title

# %%
ggplot(vl, aes(Speed, fill=Expt)) +
       geom_histogram(binwidth = 10) + xlab("Run") +
       ylab("Speed") + facet_grid(~Expt) +
       theme(legend.position="none")
# Out:
# plot without title

# %% [markdown]
# ## Este es el bueno

# %%
ggplot(vl, aes(Speed, fill=Expt)) +
       geom_histogram(binwidth = 100) + xlab("Run") +
       ylab("Speed") + facet_grid(~Expt) +
       theme(legend.position="none")
# Out:
# plot without title

# %% [raw]
# Queremos en y = speed. Aueremos que se llene con los 5 experimentos. Facetgid nos dice que solo corre una variable y queremos que se parta con eso. Solo tenemos una variable cartegórica.
# Se parte y se colorea de distintos modos

# %%
ggplot(vl, aes(Speed)) +
       geom_histogram(binwidth = 100) + xlab("Run") +
       ylab("Speed") + facet_grid(~Expt) +
       theme(legend.position="none")
# Out:
# plot without title

# %% [markdown]
# ## Pima Indians

# %%
Pima.tr2
# Out:
# Error in Pima.tr2(): could not find function "Pima.tr2"
# Traceback:

# %%
ggplot(Pima.tr2, aes(type))+ geom_bar()
# Es en la base de datos Pima.tr2, con
# Out:
# plot without title

# %%
ggplot(Pima.tr2, aes(age,npreg))+geom_point()
# Out:
# plot without title

# %%
View(Pima.tr2)
# Out:
# Error in View(Pima.tr2): ‘View()’ not yet supported in the Jupyter R kernel
# Traceback:
#
# 1. View(Pima.tr2)
# 2. stop(sQuote("View()"), " not yet supported in the Jupyter R kernel")

# %% [markdown]
# ## Titanic

# %%
head(data.frame(Titanic))
# Out:
#   Class Sex    Age   Survived Freq
# 1 1st   Male   Child No        0
# 2 2nd   Male   Child No        0
# 3 3rd   Male   Child No       35
# 4 Crew  Male   Child No        0
# 5 1st   Female Child No        0
# 6 2nd   Female Child No        0

# %%
titanic <- data.frame(Titanic)

# %%
ggplot(titanic, aes(Class)) +
       geom_histogram(binwidth = 100) + xlab("Sex") +
       ylab("") + facet_grid(~Freq) +
       theme(legend.position="none")
# Out:
# ERROR while rich displaying an object: Error: StatBin requires a continuous x variable: the x variable is discrete.Perhaps you want stat="count"?
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
# ...
