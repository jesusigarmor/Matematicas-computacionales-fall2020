# %% [markdown]
# # Python Tour

# %% [markdown]
# ## Intro
#
# python:
# - multiparadigma
# - interpretado(no se compila)
# - objetos
# - dinamico(variables pueden cambiar de tipo)
#
#
#
# jupyter - corre programas de python en la web(tambien julia,r,etc)

# %%
print("hola mundo")
# Out:
# hola mundo

# %% [markdown]
# Se pueden utilizar otros lenguajes de programación

# %%
from IPython.display import HTML

# %%
# %%html
# <table>
# <tr>
# <th>Header 1</th>
# <th>Header 12</th>
# </tr>
# <tr>
# <td>row 1, cell 1</td>
# <td>row 2, cell 1</td>
# </tr>
# Out:
# <table>
# <tr>
# <th>Header 1</th>
# <th>Header 12</th>
# </tr>
# <tr>
# <td>row 1, cell 1</td>
# <td>row 2, cell 1</td>
# </tr>

# %%
from IPython.display import Javascript

# %%
# %%javascript
#
# alert("hi");

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo("BjC0KUxiMhc")

# %%
# %timeit range(10)
# Out:
# 208 ns ± 1.56 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
